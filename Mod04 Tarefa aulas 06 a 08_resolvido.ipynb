# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'http://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio'

# %%
r = requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
data_json = r.json()

# %%
df = pd.DataFrame(data_json['items'])
df.head(5)
# Out:
#    id_pleito tipo_interessado          interessado  cod_ibge  uf  \
# 0      65245        Município       Rio de Janeiro   3304557  RJ
# 1      66686        Município  São Pedro da Aldeia   3305208  RJ
# 2      63101        Município       Rio de Janeiro   3304557  RJ
# 3      11005        Município             Araruama   3300209  RJ
# 4       7993        Município            Rio Claro   3304409  RJ
#
#                 num_pvl                                             status  \
# 0  PVL02.001203/2023-06  Encaminhado à PGFN com manifestação técnica fa...
# 1  PVL02.003206/2023-76                                           Deferido
# 2  PVL02.009023/2022-83  Encaminhado à PGFN com manifestação técnica fa...
# 3                  None                     Arquivado por decurso de prazo
# 4                  None                                           Deferido
#
#            num_processo        data_protocolo  \
# 0  17944.102641/2023-45  2023-07-26T13:58:05Z
# ...

# %%
# 2) Seu código aqui
df["status"].value_counts()
# Out:
# status
# Deferido                                                 106
# Arquivado                                                 53
# Regularizado                                              26
# Arquivado por decurso de prazo                            24
# Deferido (PVL-IF)                                         24
# Encaminhado à PGFN com manifestação técnica favorável     16
# Arquivado a pedido                                         8
# Em retificação pelo interessado                            3
# Arquivado pela STN                                         1
# Arquivado a pedido (PVL-IF)                                1
# Assinado pelo interessado (retificação)                    1
# Em retificação pelo credor                                 1
# Name: count, dtype: int64

# %% [markdown]
# ### Os três status com mais frequêcia são: "Deferido", "Arquivado" e "Regularizado" e suas frequências são: 106, 53 e 26 respectivamente

# %%
# 3) Seu código aqui
df.dtypes
# Out:
# id_pleito                  int64
# tipo_interessado          object
# interessado               object
# cod_ibge                   int64
# uf                        object
# num_pvl                   object
# status                    object
# num_processo              object
# data_protocolo            object
# tipo_operacao             object
# finalidade                object
# tipo_credor               object
# credor                    object
# moeda                     object
# valor                    float64
# pvl_assoc_divida           int64
# pvl_contradado_credor      int64
# data_status               object
# dtype: object

# %%
datas_completas = df['data_status']
datas_completas
# Out:
# 0      03/08/2023
# 1      19/09/2023
# 2      16/02/2023
# 3      09/01/2013
# 4      22/07/2011
#           ...
# 259    09/03/2007
# 260    27/12/2010
# 261    03/01/2012
# 262    12/03/2009
# 263    30/10/2008
# Name: data_status, Length: 264, dtype: object

# %%
# 4) Seu código aqui:

anos_requisicoes_completos = datas_completas.str.split('/')
anos_requisicoes_ano = anos_requisicoes_completos.str.slice(start = -1)

anos_requisicoes_ano.value_counts()
# Out:
# data_status
# [2008]    37
# [2007]    29
# [2023]    28
# [2014]    20
# [2010]    19
# [2019]    16
# [2013]    15
# [2020]    15
# [2012]    13
# [2022]    11
# [2011]    10
# [2009]     9
# [2015]     8
# [2024]     6
# [2017]     5
# [2021]     5
# [2016]     4
# [2018]     4
# [2002]     4
# [2006]     4
# [2003]     1
# [2004]     1
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def request_uf_tipo(uf: str, tipo_interessado: str):
    resposta = requests.get('https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl')
    dados = resposta.json()
    df = pd.DataFrame(dados['items'])
    
    selecao = (df['uf'] == uf) & (df['tipo_interessado'] == tipo_interessado)
    df_selecao = df[selecao]
    
    return df_selecao

# %%
# 2) Seu código aqui
uf = 'MG'
tipo_interessado = 'Estado'

df_selecao = request_uf_tipo(uf, tipo_interessado)
df_selecao.head(5)
# Out:
#       id_pleito tipo_interessado   interessado  cod_ibge  uf  \
# 1531      13672           Estado  Minas Gerais        31  MG
# 1586      13587           Estado  Minas Gerais        31  MG
# 2262      13695           Estado  Minas Gerais        31  MG
# 2327      20458           Estado  Minas Gerais        31  MG
# 2953       9197           Estado  Minas Gerais        31  MG
#
#                    num_pvl                                             status  \
# 1531                  None  Encaminhado à PGFN com manifestação técnica fa...
# 1586                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2262                  None                                          Arquivado
# 2327  00000.000000/2020-68                                 Arquivado a pedido
# 2953                  None  Encaminhado à PGFN com manifestação técnica fa...
#
#               num_processo        data_protocolo  \
# 1531  19405.000048/2005-14  2005-12-28T02:00:00Z
# ...

# %%
status = df_selecao[df_selecao['status'] == 'Arquivado por decurso de prazo'].value_counts()
status
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# ## Como a consulta mostra, não há nenhum status do tipo 'Arquivado por decurso de prazo'

# %%
# 3) Seu código aqui
uf = 'BA'
tipo_interessado = 'Município'

df_selecao = request_uf_tipo(uf, tipo_interessado)
df_selecao.head(5)
# Out:
#      id_pleito tipo_interessado    interessado  cod_ibge  uf  \
# 18       67739        Município       Juazeiro   2918407  BA
# 21       65397        Município    Nova Fátima   2922730  BA
# 26       65857        Município        Lajedão   2918902  BA
# 91       65993        Município  Santo Estêvão   2928802  BA
# 129      65435        Município   Porto Seguro   2925303  BA
#
#                   num_pvl                           status  \
# 18   PVL02.004332/2023-48  Em retificação pelo interessado
# 21   PVL02.002486/2023-03                Deferido (PVL-IF)
# 26   PVL02.002869/2023-73                Deferido (PVL-IF)
# 91   PVL02.002767/2023-58                         Deferido
# 129  PVL02.002323/2023-12                         Deferido
#
#              num_processo        data_protocolo  \
# 18   17944.000222/2024-51  2024-01-11T18:34:19Z
# 21                   None                  None
# 26                   None                  None
# ...

# %%
df_selecao_deferido = df_selecao[df_selecao['status'] == 'Deferido']
municipios = df_selecao_deferido['interessado'].value_counts()
print(municipios)
# Out:
# interessado
# Luís Eduardo Magalhães    4
# Barreiras                 3
# Mucuri                    3
# Teixeira de Freitas       3
# Santo Estêvão             3
#                          ..
# Ibicuí                    1
# Porto Seguro              1
# Feira da Mata             1
# Encruzilhada              1
# Malhada                   1
# Name: count, Length: 68, dtype: int64

# %%
mun_maisSolic = municipios.head(1)

print(mun_maisSolic)
# Out:
# interessado
# Luís Eduardo Magalhães    4
# Name: count, dtype: int64

# %% [markdown]
# ### O município da Bahia com mais solicitações 'Deferidas' é Luís Eduardo Magalhães, com 4 situações desse tipo.

# %%
# 4) Seu código aqui

uf = 'BA'
tipo_interessado = 'Estado'

df_selecao = request_uf_tipo(uf, tipo_interessado)
df_selecao.head(5)
# Out:
#       id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 4         60782           Estado       Bahia        29  BA
# 1321       8858           Estado       Bahia        29  BA
# 1369      64646           Estado       Bahia        29  BA
# 2096      12327           Estado       Bahia        29  BA
# 2318      18531           Estado       Bahia        29  BA
#
#                    num_pvl                                             status  \
# 4     PVL02.007004/2022-12                                           Deferido
# 1321                  None  Encaminhado à PGFN com manifestação técnica fa...
# 1369  PVL02.000882/2023-98                                         Em análise
# 2096                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2318                  None                                           Deferido
#
#               num_processo        data_protocolo  \
# 4     17944.102769/2022-28  2022-07-14T13:15:21Z
# ...

# %%
df_selecao.to_csv('df_selecao.csv')
df_selecao.head()
# Out:
#       id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 4         60782           Estado       Bahia        29  BA
# 1321       8858           Estado       Bahia        29  BA
# 1369      64646           Estado       Bahia        29  BA
# 2096      12327           Estado       Bahia        29  BA
# 2318      18531           Estado       Bahia        29  BA
#
#                    num_pvl                                             status  \
# 4     PVL02.007004/2022-12                                           Deferido
# 1321                  None  Encaminhado à PGFN com manifestação técnica fa...
# 1369  PVL02.000882/2023-98                                         Em análise
# 2096                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2318                  None                                           Deferido
#
#               num_processo        data_protocolo  \
# 4     17944.102769/2022-28  2022-07-14T13:15:21Z
# ...
